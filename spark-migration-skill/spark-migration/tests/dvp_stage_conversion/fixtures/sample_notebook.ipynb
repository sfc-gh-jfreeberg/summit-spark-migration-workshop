# %% [markdown]
# # Data Processing Notebook

# %%
from snowflake.snowpark import Session

# Configuration
input_path = "s3://data-lake/raw/sales.csv"
output_path = "hdfs://cluster/processed/results.parquet"

# %%
# Read data
df = session.read.csv("s3://my-bucket/data/transactions.csv")

# Dynamic path
env = "prod"
df2 = session.read.parquet(f"hdfs://{env}-cluster/warehouse/dim_customer.parquet")

# %%
# Write results
result.write.parquet("s3://output-bucket/final/report.parquet")
